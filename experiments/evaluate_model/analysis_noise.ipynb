# %%
import os
import json
import pandas as pd
import spacy
from tqdm import tqdm
from collections import defaultdict, Counter
from pprint import pprint

# %%
def get_result(eval_type, evaluate_id):
    evaluated_dpath = "/data/group1/z44383r/dev/rl-nlg/experiments/evaluate_model/outputs"
    evaluated_result_fpath = os.path.join(evaluated_dpath, eval_type, evaluate_id, "result.json")
    result = json.load(open(evaluated_result_fpath))
    return result

# %%
def compute_acc_by_da(result):
    def update_acc(acc, key, i, d, s):
        ids = f"{i}-{d}-{s}"
        if ids not in acc:
            acc[ids] = {'tp': 0, 'fn': 0, 'fp': 0}
        acc[ids][key] += 1

    acc = {}
    for r in tqdm(result):
        for i,d,s,v in r["tp_acts"]:
            update_acc(acc, 'tp', i, d, s)
        for i,d,s,v in r["fn_acts"]:
            update_acc(acc, 'fn', i, d, s)
        for i,d,s,v in r["fp_acts"]:
            update_acc(acc, 'fp', i, d, s)

    for ids in acc:
        acc[ids]['tp_ratio'] = acc[ids]['tp'] / sum(acc[ids].values())
        acc[ids]['fn_ratio'] = acc[ids]['fn'] / sum(acc[ids].values())
        acc[ids]['fp_ratio'] = acc[ids]['fp'] / sum(acc[ids].values())
        acc[ids]['num_acts'] = sum(acc[ids][key] for key in ['tp', 'fn', 'fp'])

    return acc

# %%
def compute_diff(gpt2_acc, ppo_acc):
    diff = {}
    for ids in gpt2_acc:
        if ids not in ppo_acc:
            continue
        diff[ids] = {
            'tp_ratio': ppo_acc[ids]['tp_ratio'] - gpt2_acc[ids]['tp_ratio'],
            'fn_ratio': ppo_acc[ids]['fn_ratio'] - gpt2_acc[ids]['fn_ratio'],
            'fp_ratio': ppo_acc[ids]['fp_ratio'] - gpt2_acc[ids]['fp_ratio'],
            'num_acts': gpt2_acc[ids]['num_acts'] + ppo_acc[ids]['num_acts']
        }
    return diff

# %%
def search_ppo_win_turns(ids, result_gpt2, result_ppo, is_win_wer=False):
    text_keys = ['gen_text', 'noised_text']
    acts_keys = ['tp_acts', 'fn_acts', 'fp_acts']
    def is_ids_in(acts):
        for i, d, s, v in acts:
            if ids == f'{i}-{d}-{s}':
                return True
        return False

    def tuple2strings(acts):
        return [f'{i}-{d}-{s}-{v}' for i,d,s,v in acts]

    ppo_win_turns = []
    for r_gpt2, r_ppo in zip(result_gpt2, result_ppo):
        if is_win_wer and r_gpt2['noised_wer'] < r_ppo['noised_wer']:
            continue
        if not is_ids_in(r_gpt2['tp_acts']) and is_ids_in(r_ppo['tp_acts']):
            ppo_win_turns.append({
                'action': tuple2strings(r_gpt2['action']),
                'gpt2': {
                    **{key: r_gpt2[key] for key in text_keys},
                    **{key: tuple2strings(r_gpt2[key]) for key in acts_keys}
                },
                'ppo': {
                    **{key: r_ppo[key] for key in text_keys},
                    **{key: tuple2strings(r_ppo[key]) for key in acts_keys}
                }
            })
    return ppo_win_turns

# %%
result_gpt2_bert_0 = get_result("baselines", "gpt2-bert-full-sys-background(0)")
acc_by_da_gpt2_bert_0 = compute_acc_by_da(result_gpt2_bert_0)

result_ppo_bert_0 = get_result("ppo", "bert-full-sys-noise-background(0)-seed12")
acc_by_da_ppo_bert_0 = compute_acc_by_da(result_ppo_bert_0)

diff_gpt2_ppo_bert_0 = compute_diff(acc_by_da_gpt2_bert_0, acc_by_da_ppo_bert_0)
pprint(sorted(diff_gpt2_ppo_bert_0.items(), key=lambda x: x[1]['tp_ratio'], reverse=True))
# Out:
# 100%|██████████| 7372/7372 [00:00<00:00, 529205.33it/s]
# 100%|██████████| 7372/7372 [00:00<00:00, 553652.93it/s]
# [('Inform-Police-Addr',
#   {'fn_ratio': -1.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 1.0}),
#  ('NoOffer-Hotel-Internet',
#   {'fn_ratio': -1.0,
#    'fp_ratio': 0.1724137931034483,
#    'num_acts': 9,
#    'tp_ratio': 0.8}),
#  ('Request-Taxi-Depart',
#   {'fn_ratio': -0.6237870081293455,
#    'fp_ratio': 0.07758080086491426,
#    'num_acts': 166,
#    'tp_ratio': 0.5469227411610651}),
#  ('Request-Taxi-Leave',
#   {'fn_ratio': -0.05728465877021535,
#    'fp_ratio': -0.3617903432143894,
#    'num_acts': 230,
#    'tp_ratio': 0.41949423815620995}),
#  ('Request-Hotel-Parking',
#   {'fn_ratio': -0.3673469387755102,
#    'fp_ratio': -0.03700376767262281,
#    'num_acts': 47,
#    'tp_ratio': 0.4130434782608695}),
#  ('OfferBook-Train-Day',
#   {'fn_ratio': 0.0,
#    'fp_ratio': -0.35714285714285715,
#    'num_acts': 8,
#    'tp_ratio': 0.4}),
#  ('NoOffer-Attraction-none',
#   {'fn_ratio': -0.5132210256957032,
#    'fp_ratio': 0.13160838350719298,
#    'num_acts': 33,
#    'tp_ratio': 0.37777777777777777}),
#  ('NoOffer-Train-none',
#   {'fn_ratio': -0.3243243243243243,
#    'fp_ratio': -0.0006405807932524654,
#    'num_acts': 12,
#    'tp_ratio': 0.33333333333333337}),
#  ('Request-Taxi-Arrive',
#   {'fn_ratio': -0.14554618932179236,
#    'fp_ratio': -0.14768372327633322,
#    'num_acts': 125,
#    'tp_ratio': 0.29399585921325055}),
#  ('Inform-Taxi-Leave',
#   {'fn_ratio': -0.15004503398018504,
#    'fp_ratio': -0.1360562432891239,
#    'num_acts': 42,
#    'tp_ratio': 0.2814645308924485}),
#  ('OfferBooked-Train-Dest',
#   {'fn_ratio': -0.06766839734552826,
#    'fp_ratio': -0.21534351474158206,
#    'num_acts': 26,
#    'tp_ratio': 0.27878787878787875}),
#  ('Recommend-Restaurant-Price',
#   {'fn_ratio': -0.24773666474042383,
#    'fp_ratio': -0.029470234875456386,
#    'num_acts': 53,
#    'tp_ratio': 0.27492877492877493}),
#  ('Select-Train-none',
#   {'fn_ratio': -0.05121616992120587,
#    'fp_ratio': -0.2192050977567217,
#    'num_acts': 81,
#    'tp_ratio': 0.2690863579474343}),
#  ('Recommend-Hotel-Internet',
#   {'fn_ratio': -0.22513661202185797,
#    'fp_ratio': -0.04553835144827697,
#    'num_acts': 39,
#    'tp_ratio': 0.2631578947368421}),
#  ('NoOffer-Hotel-none',
#   {'fn_ratio': -0.19335624284077893,
#    'fp_ratio': -0.05686740156120168,
#    'num_acts': 46,
#    'tp_ratio': 0.25}),
#  ('OfferBooked-Train-Day',
#   {'fn_ratio': -0.03471418653089561,
#    'fp_ratio': -0.21471820407908815,
#    'num_acts': 21,
#    'tp_ratio': 0.24999999999999994}),
#  ('Request-Hotel-Internet',
#   {'fn_ratio': -0.32916858590511283,
#    'fp_ratio': 0.09107977809540657,
#    'num_acts': 38,
#    'tp_ratio': 0.24444444444444446}),
#  ('Request-Attraction-Area',
#   {'fn_ratio': -0.20338174910572526,
#    'fp_ratio': -0.01895757386448038,
#    'num_acts': 182,
#    'tp_ratio': 0.22342995169082125}),
#  ('Inform-Hotel-Internet',
#   {'fn_ratio': -0.2422365864500022,
#    'fp_ratio': 0.019699518583922423,
#    'num_acts': 287,
#    'tp_ratio': 0.2231180184555609}),
#  ('Request-Hotel-Price',
#   {'fn_ratio': -0.08857135208734732,
#    'fp_ratio': -0.12557446218022147,
#    'num_acts': 265,
#    'tp_ratio': 0.21498912172220308}),
#  ('Request-Train-Depart',
#   {'fn_ratio': -0.013014523984238986,
#    'fp_ratio': -0.20129433333740965,
#    'num_acts': 469,
#    'tp_ratio': 0.21480989785005722}),
#  ('Request-Taxi-Dest',
#   {'fn_ratio': -0.1547477626421887,
#    'fp_ratio': -0.05706612371391906,
#    'num_acts': 141,
#    'tp_ratio': 0.2127316680096697}),
#  ('Request-Train-Dest',
#   {'fn_ratio': -0.08611382804837606,
#    'fp_ratio': -0.11354897464948864,
#    'num_acts': 396,
#    'tp_ratio': 0.2001024721403868}),
#  ('Select-Attraction-Area',
#   {'fn_ratio': -0.30065359477124176,
#    'fp_ratio': 0.0842635364463995,
#    'num_acts': 19,
#    'tp_ratio': 0.2}),
#  ('Select-Train-Day',
#   {'fn_ratio': -0.22307692307692317,
#    'fp_ratio': 0.0006887368566049767,
#    'num_acts': 10,
#    'tp_ratio': 0.2}),
#  ('Request-Train-Leave',
#   {'fn_ratio': -0.004020344648045557,
#    'fp_ratio': -0.18737702804297096,
#    'num_acts': 543,
#    'tp_ratio': 0.19164079030529535}),
#  ('OfferBook-Train-Dest',
#   {'fn_ratio': -0.08631578947368412,
#    'fp_ratio': -0.11273670041910125,
#    'num_acts': 13,
#    'tp_ratio': 0.19047619047619047}),
#  ('Recommend-Attraction-Fee',
#   {'fn_ratio': -0.0596949729230572,
#    'fp_ratio': -0.12077882162057402,
#    'num_acts': 122,
#    'tp_ratio': 0.17937584803256443}),
#  ('OfferBook-Train-none',
#   {'fn_ratio': -0.17364787787389302,
#    'fp_ratio': 0.010800985357785467,
#    'num_acts': 714,
#    'tp_ratio': 0.16304288124288913}),
#  ('greet-general-none',
#   {'fn_ratio': -0.13433965213267962,
#    'fp_ratio': -0.008027398637975556,
#    'num_acts': 482,
#    'tp_ratio': 0.14194214876033057}),
#  ('Recommend-Hotel-Parking',
#   {'fn_ratio': 0.017125826257214705,
#    'fp_ratio': -0.1601201595509906,
#    'num_acts': 42,
#    'tp_ratio': 0.14187643020594964}),
#  ('Request-Hotel-Area',
#   {'fn_ratio': -0.0707567901128546,
#    'fp_ratio': -0.0682368417598589,
#    'num_acts': 406,
#    'tp_ratio': 0.139287884311581}),
#  ('Inform-Taxi-Arrive',
#   {'fn_ratio': 0.07530454042081947,
#    'fp_ratio': -0.20499755843159553,
#    'num_acts': 28,
#    'tp_ratio': 0.125}),
#  ('Inform-Booking-Day',
#   {'fn_ratio': -0.19170865781035276,
#    'fp_ratio': 0.07413157386727576,
#    'num_acts': 36,
#    'tp_ratio': 0.1207430340557275}),
#  ('NoOffer-Attraction-Type',
#   {'fn_ratio': 0.05645512746996245,
#    'fp_ratio': -0.1767872756442445,
#    'num_acts': 102,
#    'tp_ratio': 0.11929824561403513}),
#  ('Select-Hotel-none',
#   {'fn_ratio': -0.1288065298634013,
#    'fp_ratio': 0.011155002340489106,
#    'num_acts': 131,
#    'tp_ratio': 0.11748251748251748}),
#  ('Select-Restaurant-Food',
#   {'fn_ratio': 0.15470194506113522,
#    'fp_ratio': -0.26059392011328875,
#    'num_acts': 59,
#    'tp_ratio': 0.1023809523809524}),
#  ('Book-Booking-Ref',
#   {'fn_ratio': -0.009916807557665275,
#    'fp_ratio': -0.08289026334116517,
#    'num_acts': 1771,
#    'tp_ratio': 0.09275979229437786}),
#  ('Inform-Restaurant-Choice',
#   {'fn_ratio': -0.04537308964750009,
#    'fp_ratio': -0.04482308900677734,
#    'num_acts': 930,
#    'tp_ratio': 0.09014993357373319}),
#  ('Request-Booking-Time',
#   {'fn_ratio': -0.06458982217201067,
#    'fp_ratio': -0.023764214957299287,
#    'num_acts': 237,
#    'tp_ratio': 0.0888888888888888}),
#  ('Request-Train-Arrive',
#   {'fn_ratio': 0.06481749909935694,
#    'fp_ratio': -0.14706677087581446,
#    'num_acts': 260,
#    'tp_ratio': 0.08211983767008835}),
#  ('Recommend-Attraction-Type',
#   {'fn_ratio': -0.06691012761335863,
#    'fp_ratio': -0.014940151479252317,
#    'num_acts': 77,
#    'tp_ratio': 0.08097165991902833}),
#  ('Recommend-Attraction-Area',
#   {'fn_ratio': 0.005687625147806574,
#    'fp_ratio': -0.08771756098543959,
#    'num_acts': 95,
#    'tp_ratio': 0.08065953654188948}),
#  ('Inform-Booking-none',
#   {'fn_ratio': -0.05440188550239336,
#    'fp_ratio': -0.025935974405696477,
#    'num_acts': 1095,
#    'tp_ratio': 0.08043043043043041}),
#  ('OfferBooked-Train-Ref',
#   {'fn_ratio': -0.05568624379757656,
#    'fp_ratio': -0.024031265611013042,
#    'num_acts': 933,
#    'tp_ratio': 0.0797078131033595}),
#  ('Request-Attraction-Name',
#   {'fn_ratio': 0.3081340279422211,
#    'fp_ratio': -0.39468513813398465,
#    'num_acts': 28,
#    'tp_ratio': 0.07777777777777778}),
#  ('Inform-Booking-People',
#   {'fn_ratio': 0.11176470588235299,
#    'fp_ratio': -0.19427440133509155,
#    'num_acts': 31,
#    'tp_ratio': 0.07692307692307693}),
#  ('Select-Attraction-none',
#   {'fn_ratio': -0.032849593154936574,
#    'fp_ratio': -0.04062805988698104,
#    'num_acts': 74,
#    'tp_ratio': 0.07309941520467839}),
#  ('Inform-Taxi-Depart',
#   {'fn_ratio': -0.0327382892303566,
#    'fp_ratio': -0.04073685714315617,
#    'num_acts': 91,
#    'tp_ratio': 0.0725338491295938}),
#  ('Book-Booking-Time',
#   {'fn_ratio': 0.022643890919207377,
#    'fp_ratio': -0.09555805511410087,
#    'num_acts': 187,
#    'tp_ratio': 0.07241379310344828}),
#  ('Inform-Train-Depart',
#   {'fn_ratio': -0.06560212091735668,
#    'fp_ratio': -0.006752593902336068,
#    'num_acts': 464,
#    'tp_ratio': 0.07234825260576333}),
#  ('Recommend-Attraction-Name',
#   {'fn_ratio': -0.04489975820447539,
#    'fp_ratio': -0.025054084406916755,
#    'num_acts': 488,
#    'tp_ratio': 0.06980222143805347}),
#  ('Request-Booking-People',
#   {'fn_ratio': 0.015510800206675016,
#    'fp_ratio': -0.08428636271756726,
#    'num_acts': 262,
#    'tp_ratio': 0.0690802919708029}),
#  ('Request-Restaurant-Area',
#   {'fn_ratio': 0.031572962532543436,
#    'fp_ratio': -0.09880021936017427,
#    'num_acts': 232,
#    'tp_ratio': 0.06727828746177378}),
#  ('Request-Restaurant-Name',
#   {'fn_ratio': -0.20714285714285716,
#    'fp_ratio': 0.14669926650366746,
#    'num_acts': 11,
#    'tp_ratio': 0.06666666666666665}),
#  ('Select-Restaurant-none',
#   {'fn_ratio': -0.05467007485980874,
#    'fp_ratio': -0.010214737961283915,
#    'num_acts': 137,
#    'tp_ratio': 0.06500426257459507}),
#  ('Request-Restaurant-Price',
#   {'fn_ratio': -0.047208629482638764,
#    'fp_ratio': -0.016787756671487963,
#    'num_acts': 196,
#    'tp_ratio': 0.06425075497240451}),
#  ('Select-Hotel-Price',
#   {'fn_ratio': 0.14676034348165495,
#    'fp_ratio': -0.21099998249041868,
#    'num_acts': 44,
#    'tp_ratio': 0.06315789473684208}),
#  ('NoOffer-Restaurant-Price',
#   {'fn_ratio': -0.025165677064669656,
#    'fp_ratio': -0.038045382556553986,
#    'num_acts': 43,
#    'tp_ratio': 0.06277056277056275}),
#  ('Select-Attraction-Type',
#   {'fn_ratio': 0.18107153103906493,
#    'fp_ratio': -0.24292992931541477,
#    'num_acts': 128,
#    'tp_ratio': 0.0608805031446541}),
#  ('Inform-Train-Day',
#   {'fn_ratio': -0.03595632069035021,
#    'fp_ratio': -0.022860613574667704,
#    'num_acts': 247,
#    'tp_ratio': 0.05908196721311476}),
#  ('Inform-Restaurant-Price',
#   {'fn_ratio': -0.07080943717730626,
#    'fp_ratio': 0.0121063702974325,
#    'num_acts': 540,
#    'tp_ratio': 0.058768656716417955}),
#  ('NoOffer-Hotel-Type',
#   {'fn_ratio': -0.07045680326942405,
#    'fp_ratio': 0.014826585287121191,
#    'num_acts': 101,
#    'tp_ratio': 0.05529411764705883}),
#  ('Inform-Attraction-Type',
#   {'fn_ratio': -0.013538207211832243,
#    'fp_ratio': -0.03939263512095209,
#    'num_acts': 851,
#    'tp_ratio': 0.05288583778286293}),
#  ('Recommend-Hotel-Area',
#   {'fn_ratio': -0.09721517210727615,
#    'fp_ratio': 0.04452317615874629,
#    'num_acts': 97,
#    'tp_ratio': 0.0523404255319149}),
#  ('reqmore-general-none',
#   {'fn_ratio': -0.019260023587419878,
#    'fp_ratio': -0.03198518317337438,
#    'num_acts': 2969,
#    'tp_ratio': 0.05127136723040748}),
#  ('Recommend-Restaurant-Area',
#   {'fn_ratio': -0.02002157787834624,
#    'fp_ratio': -0.03174991196163218,
#    'num_acts': 84,
#    'tp_ratio': 0.05104934770277936}),
#  ('NoOffer-Hotel-Price',
#   {'fn_ratio': -0.11916058204989094,
#    'fp_ratio': 0.0704711375692069,
#    'num_acts': 46,
#    'tp_ratio': 0.0492424242424242}),
#  ('Book-Booking-Stay',
#   {'fn_ratio': 0.005731962514784805,
#    'fp_ratio': -0.055385925593693625,
#    'num_acts': 106,
#    'tp_ratio': 0.04919786096256687}),
#  ('NoOffer-Restaurant-Area',
#   {'fn_ratio': -0.08529835542608233,
#    'fp_ratio': 0.04125312556671723,
#    'num_acts': 120,
#    'tp_ratio': 0.0439377085650723}),
#  ('Select-Hotel-Stars',
#   {'fn_ratio': -0.12070681077371764,
#    'fp_ratio': 0.08152502565919495,
#    'num_acts': 37,
#    'tp_ratio': 0.0411764705882353}),
#  ('NoBook-Booking-Time',
#   {'fn_ratio': 0.08535300316122235,
#    'fp_ratio': -0.12636268354662394,
#    'num_acts': 35,
#    'tp_ratio': 0.03947368421052633}),
#  ('Inform-Train-Choice',
#   {'fn_ratio': -0.02428458239569753,
#    'fp_ratio': -0.013040887035436433,
#    'num_acts': 820,
#    'tp_ratio': 0.037302777182837143}),
#  ('Inform-Booking-Name',
#   {'fn_ratio': 0.06093811254383824,
#    'fp_ratio': -0.09790682248922117,
#    'num_acts': 98,
#    'tp_ratio': 0.03535353535353536}),
#  ('Inform-Taxi-Phone',
#   {'fn_ratio': -0.04575316908005524,
#    'fp_ratio': 0.013155614673398097,
#    'num_acts': 494,
#    'tp_ratio': 0.03270223752151458}),
#  ('Inform-Attraction-Choice',
#   {'fn_ratio': -0.026120357700762764,
#    'fp_ratio': -0.006362320333501759,
#    'num_acts': 681,
#    'tp_ratio': 0.03247425348030841}),
#  ('Recommend-Restaurant-Food',
#   {'fn_ratio': -0.1596878937184455,
#    'fp_ratio': 0.12992458427420192,
#    'num_acts': 83,
#    'tp_ratio': 0.02982456140350878}),
#  ('Request-Attraction-Type',
#   {'fn_ratio': -0.04735553543175476,
#    'fp_ratio': 0.01907080600210101,
#    'num_acts': 178,
#    'tp_ratio': 0.028535353535353525}),
#  ('Select-Restaurant-Price',
#   {'fn_ratio': -0.027753835746651134,
#    'fp_ratio': -1.7757737397205986e-07,
#    'num_acts': 72,
#    'tp_ratio': 0.02777777777777779}),
#  ('OfferBooked-Train-People',
#   {'fn_ratio': -0.03808327001601297,
#    'fp_ratio': 0.010609176326983438,
#    'num_acts': 133,
#    'tp_ratio': 0.027363184079602004}),
#  ('Recommend-Hotel-Price',
#   {'fn_ratio': -0.010910020118337638,
#    'fp_ratio': -0.01632840151435261,
#    'num_acts': 87,
#    'tp_ratio': 0.026955602536997886}),
#  ('bye-general-none',
#   {'fn_ratio': -0.014630476817320673,
#    'fp_ratio': -0.012125232775461708,
#    'num_acts': 1965,
#    'tp_ratio': 0.02677609441562101}),
#  ('Inform-Hotel-Stars',
#   {'fn_ratio': -0.0191787149303263,
#    'fp_ratio': -0.006704227372181293,
#    'num_acts': 555,
#    'tp_ratio': 0.02582982702197288}),
#  ('Recommend-Hotel-Stars',
#   {'fn_ratio': 0.011393865581231344,
#    'fp_ratio': -0.0372801552509284,
#    'num_acts': 80,
#    'tp_ratio': 0.02564102564102564}),
#  ('Inform-Hotel-Choice',
#   {'fn_ratio': -0.03745456581872675,
#    'fp_ratio': 0.011950705203518375,
#    'num_acts': 1067,
#    'tp_ratio': 0.02550228037750968}),
#  ('Inform-Attraction-Addr',
#   {'fn_ratio': 0.02894975406436312,
#    'fp_ratio': -0.051701685942262654,
#    'num_acts': 1163,
#    'tp_ratio': 0.022699797328529267}),
#  ('Book-Booking-People',
#   {'fn_ratio': -0.008133614579113324,
#    'fp_ratio': -0.010741413248071152,
#    'num_acts': 238,
#    'tp_ratio': 0.018785310734463267}),
#  ('Inform-Restaurant-Name',
#   {'fn_ratio': 0.023105966419461277,
#    'fp_ratio': -0.0404666345873651,
#    'num_acts': 1162,
#    'tp_ratio': 0.017325029655990518}),
#  ('Inform-Hotel-Addr',
#   {'fn_ratio': 0.01693909530818466,
#    'fp_ratio': -0.030675862790924935,
#    'num_acts': 417,
#    'tp_ratio': 0.013650384420606787}),
#  ('Inform-Restaurant-Addr',
#   {'fn_ratio': 0.012906791862123512,
#    'fp_ratio': -0.025597641054910747,
#    'num_acts': 547,
#    'tp_ratio': 0.012627073301230602}),
#  ('Inform-Hotel-Price',
#   {'fn_ratio': 0.02089865425371118,
#    'fp_ratio': -0.03343219630481034,
#    'num_acts': 545,
#    'tp_ratio': 0.012515830032603148}),
#  ('Inform-Taxi-Car',
#   {'fn_ratio': -0.005636004879249423,
#    'fp_ratio': -0.00675542846326177,
#    'num_acts': 599,
#    'tp_ratio': 0.01237485785636247}),
#  ('Recommend-Hotel-Name',
#   {'fn_ratio': -0.013053169459125102,
#    'fp_ratio': 0.005221985046526878,
#    'num_acts': 460,
#    'tp_ratio': 0.007826234900470713}),
#  ('Inform-Train-Leave',
#   {'fn_ratio': -0.00349473269636269,
#    'fp_ratio': -0.003913198558334219,
#    'num_acts': 1555,
#    'tp_ratio': 0.007402812241521922}),
#  ('Inform-Attraction-Area',
#   {'fn_ratio': 0.020076360795088566,
#    'fp_ratio': -0.026379538502229183,
#    'num_acts': 896,
#    'tp_ratio': 0.0062804364404878965}),
#  ('OfferBooked-Train-Ticket',
#   {'fn_ratio': 0.056523225444951475,
#    'fp_ratio': -0.06118481343863402,
#    'num_acts': 654,
#    'tp_ratio': 0.004587026874912057}),
#  ('Inform-Train-Ref',
#   {'fn_ratio': 0.06535815579643361,
#    'fp_ratio': -0.07122529185610249,
#    'num_acts': 86,
#    'tp_ratio': 0.00436442989634479}),
#  ('Inform-Attraction-Fee',
#   {'fn_ratio': 0.0001931786175257133,
#    'fp_ratio': -0.004455467824202419,
#    'num_acts': 777,
#    'tp_ratio': 0.004253627509441443}),
#  ('Request-Train-People',
#   {'fn_ratio': -0.0274241184907337,
#    'fp_ratio': 0.024103801692405356,
#    'num_acts': 162,
#    'tp_ratio': 0.0033536585365853133}),
#  ('Inform-Attraction-Post',
#   {'fn_ratio': -0.02171474108860072,
#    'fp_ratio': 0.018416576605891966,
#    'num_acts': 564,
#    'tp_ratio': 0.003295265885193943}),
#  ('Request-Train-Day',
#   {'fn_ratio': -0.015223904789123222,
#    'fp_ratio': 0.013624519144172235,
#    'num_acts': 423,
#    'tp_ratio': 0.0016096579476861939}),
#  ('Inform-Attraction-Phone',
#   {'fn_ratio': 0.010121290881530687,
#    'fp_ratio': -0.010150260462192973,
#    'num_acts': 493,
#    'tp_ratio': 4.937458854509594e-05}),
#  ('NoOffer-Restaurant-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('OfferBook-Train-Leave',
#   {'fn_ratio': 0.14479638009049778,
#    'fp_ratio': -0.1464617569886958,
#    'num_acts': 60,
#    'tp_ratio': 0.0}),
#  ('Inform-Booking-Time',
#   {'fn_ratio': -0.17142857142857143,
#    'fp_ratio': 0.18131868131868129,
#    'num_acts': 12,
#    'tp_ratio': 0.0}),
#  ('Inform-Hotel-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('Inform-Hotel-Phone',
#   {'fn_ratio': 0.023544973544973535,
#    'fp_ratio': -0.023433022533685177,
#    'num_acts': 213,
#    'tp_ratio': 0.0}),
#  ('NoOffer-Attraction-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Hotel-Name',
#   {'fn_ratio': -0.032967032967033016,
#    'fp_ratio': 0.034455445544554375,
#    'num_acts': 27,
#    'tp_ratio': 0.0}),
#  ('Inform-Restaurant-Ref',
#   {'fn_ratio': 0.2222222222222222,
#    'fp_ratio': -0.2350557244174265,
#    'num_acts': 28,
#    'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Addr',
#   {'fn_ratio': -0.1883042429040207,
#    'fp_ratio': 0.18859533993316935,
#    'num_acts': 133,
#    'tp_ratio': 0.0}),
#  ('OfferBook-Train-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Recommend-Hotel-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Phone',
#   {'fn_ratio': -0.25,
#    'fp_ratio': 0.21052631578947367,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('Select-Hotel-Type',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 46, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Leave',
#   {'fn_ratio': -0.16666666666666663,
#    'fp_ratio': 0.17171717171717166,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Phone',
#   {'fn_ratio': -0.1568627450980392,
#    'fp_ratio': 0.15476009139375474,
#    'num_acts': 38,
#    'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Post',
#   {'fn_ratio': -0.09661835748792269,
#    'fp_ratio': 0.09724857685009486,
#    'num_acts': 50,
#    'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('Inform-Police-Phone',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Select-Train-Leave',
#   {'fn_ratio': -0.23333333333333328,
#    'fp_ratio': 0.2368675475346439,
#    'num_acts': 25,
#    'tp_ratio': 0.0}),
#  ('Inform-Taxi-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 14, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Dest',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Arrive',
#   {'fn_ratio': -0.16666666666666669,
#    'fp_ratio': 0.19999999999999996,
#    'num_acts': 5,
#    'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-Post',
#   {'fn_ratio': -0.09999999999999998,
#    'fp_ratio': 0.10264150943396222,
#    'num_acts': 22,
#    'tp_ratio': 0.0}),
#  ('Inform-Restaurant-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 10, 'tp_ratio': 0.0}),
#  ('Inform-Attraction-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Hotel-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Inform-Train-People',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('NoOffer-Hotel-Name',
#   {'fn_ratio': -0.33333333333333337,
#    'fp_ratio': 0.27272727272727276,
#    'num_acts': 5,
#    'tp_ratio': 0.0}),
#  ('Select-Attraction-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 22, 'tp_ratio': 0.0}),
#  ('Inform-Booking-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('OfferBooked-Train-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 10, 'tp_ratio': 0.0}),
#  ('Inform-Train-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('OfferBook-Train-Depart',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-Phone',
#   {'fn_ratio': 0.13333333333333341,
#    'fp_ratio': -0.1275862068965517,
#    'num_acts': 11,
#    'tp_ratio': 0.0}),
#  ('Inform-Hospital-Phone',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-Name',
#   {'fn_ratio': 0.6666666666666667,
#    'fp_ratio': -0.6,
#    'num_acts': 4,
#    'tp_ratio': 0.0}),
#  ('OfferBook-Train-People',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 12, 'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Day',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Inform-Hotel-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Post',
#   {'fn_ratio': -0.4444444444444444,
#    'fp_ratio': 0.4186046511627907,
#    'num_acts': 14,
#    'tp_ratio': 0.0}),
#  ('Inform-Attraction-Price',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 18, 'tp_ratio': 0.0}),
#  ('Recommend-Attraction-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Select-Restaurant-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Attraction-Price',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('OfferBook-Train-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Attraction-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Inform-Police-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Inform-Hospital-Department',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Train-Id',
#   {'fn_ratio': -0.5, 'fp_ratio': 0.4, 'num_acts': 3, 'tp_ratio': 0.0}),
#  ('Inform-Attraction-Open',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Inform-Restaurant-Phone',
#   {'fn_ratio': -0.010580242526206818,
#    'fp_ratio': 0.010681298361323754,
#    'num_acts': 268,
#    'tp_ratio': -0.0001113895850737949}),
#  ('Inform-Restaurant-Area',
#   {'fn_ratio': 0.02563625291190902,
#    'fp_ratio': -0.024672609781365484,
#    'num_acts': 834,
#    'tp_ratio': -0.0009837480224363648}),
#  ('Recommend-Hotel-Type',
#   {'fn_ratio': -0.026533629381897073,
#    'fp_ratio': 0.02822040655571556,
#    'num_acts': 49,
#    'tp_ratio': -0.0016666666666666635}),
#  ('Inform-Hotel-Name',
#   {'fn_ratio': 0.006746588763118733,
#    'fp_ratio': -0.003675418850276446,
#    'num_acts': 1105,
#    'tp_ratio': -0.003069574845866077}),
#  ('Request-Booking-Day',
#   {'fn_ratio': -0.026225986250579432,
#    'fp_ratio': 0.03114838604841553,
#    'num_acts': 419,
#    'tp_ratio': -0.004922740325447816}),
#  ('Inform-Restaurant-Food',
#   {'fn_ratio': -0.006976879405359793,
#    'fp_ratio': 0.012855071865155915,
#    'num_acts': 764,
#    'tp_ratio': -0.005873282390432832}),
#  ('OfferBook-Train-Id',
#   {'fn_ratio': -0.11585005903187717,
#    'fp_ratio': 0.12410882237997073,
#    'num_acts': 64,
#    'tp_ratio': -0.006896551724137917}),
#  ('Inform-Attraction-Name',
#   {'fn_ratio': 0.021498326697393044,
#    'fp_ratio': -0.01379750740534813,
#    'num_acts': 1189,
#    'tp_ratio': -0.007702581864692623}),
#  ('Inform-Hotel-Post',
#   {'fn_ratio': -0.02977160199163842,
#    'fp_ratio': 0.038495357633667904,
#    'num_acts': 276,
#    'tp_ratio': -0.008570376991429622}),
#  ('Inform-Train-Id',
#   {'fn_ratio': 0.0245258002018387,
#    'fp_ratio': -0.015520772359341586,
#    'num_acts': 803,
#    'tp_ratio': -0.008995595260251843}),
#  ('Inform-Train-Ticket',
#   {'fn_ratio': -0.028568265223290146,
#    'fp_ratio': 0.03938187949129418,
#    'num_acts': 526,
#    'tp_ratio': -0.010739925891616486}),
#  ('Inform-Restaurant-Post',
#   {'fn_ratio': 0.05244626741635161,
#    'fp_ratio': -0.041622856187238044,
#    'num_acts': 328,
#    'tp_ratio': -0.010871183916604616}),
#  ('Request-Restaurant-Food',
#   {'fn_ratio': 0.011184415363380246,
#    'fp_ratio': 9.6550019160202e-09,
#    'num_acts': 356,
#    'tp_ratio': -0.011235955056179803}),
#  ('OfferBooked-Train-Leave',
#   {'fn_ratio': 0.0248770790596744,
#    'fp_ratio': -0.013533611947847968,
#    'num_acts': 136,
#    'tp_ratio': -0.011464417045208744}),
#  ('Inform-Hotel-Area',
#   {'fn_ratio': 0.028754945531204,
#    'fp_ratio': -0.015022199355957333,
#    'num_acts': 594,
#    'tp_ratio': -0.013741496598639436}),
#  ('welcome-general-none',
#   {'fn_ratio': 0.01870229294796638,
#    'fp_ratio': -0.003952587002141239,
#    'num_acts': 1006,
#    'tp_ratio': -0.01476633149939921}),
#  ('NoBook-Booking-Stay',
#   {'fn_ratio': -0.05067379440917685,
#    'fp_ratio': 0.06606260851589157,
#    'num_acts': 23,
#    'tp_ratio': -0.015151515151515166}),
#  ('Inform-Train-Arrive',
#   {'fn_ratio': -0.014954499409897903,
#    'fp_ratio': 0.03245473259605086,
#    'num_acts': 1150,
#    'tp_ratio': -0.017474253167851478}),
#  ('Request-Hotel-Type',
#   {'fn_ratio': 0.04417364032817628,
#    'fp_ratio': -0.026128569236924082,
#    'num_acts': 59,
#    'tp_ratio': -0.01839080459770115}),
#  ('Recommend-Restaurant-Name',
#   {'fn_ratio': 0.01911753809688088,
#    'fp_ratio': 0.0026925323846295757,
#    'num_acts': 469,
#    'tp_ratio': -0.02176759410801965}),
#  ('NoOffer-Attraction-Area',
#   {'fn_ratio': 0.09254856209354423,
#    'fp_ratio': -0.06856360520134952,
#    'num_acts': 114,
#    'tp_ratio': -0.02407407407407408}),
#  ('Select-Attraction-Fee',
#   {'fn_ratio': -0.09626808834729628,
#    'fp_ratio': 0.1282335771020831,
#    'num_acts': 18,
#    'tp_ratio': -0.024999999999999994}),
#  ('Request-Hotel-Stars',
#   {'fn_ratio': 0.1856197937647881,
#    'fp_ratio': -0.1591996799593095,
#    'num_acts': 86,
#    'tp_ratio': -0.027277686852154925}),
#  ('Select-Restaurant-Name',
#   {'fn_ratio': -0.03400116257729724,
#    'fp_ratio': 0.0637372433964859,
#    'num_acts': 89,
#    'tp_ratio': -0.028875379939209724}),
#  ('Inform-Hotel-Type',
#   {'fn_ratio': -0.026923872526062542,
#    'fp_ratio': 0.056715648208445074,
#    'num_acts': 843,
#    'tp_ratio': -0.029748012853035688}),
#  ('Book-Booking-Name',
#   {'fn_ratio': 0.04564579925844353,
#    'fp_ratio': -0.012357982593962369,
#    'num_acts': 338,
#    'tp_ratio': -0.03326679973386559}),
#  ('NoOffer-Restaurant-Food',
#   {'fn_ratio': -0.05699120135813729,
#    'fp_ratio': 0.09409764007707828,
#    'num_acts': 161,
#    'tp_ratio': -0.036996904024767796}),
#  ('OfferBooked-Train-Arrive',
#   {'fn_ratio': -0.06430618581323144,
#    'fp_ratio': 0.10428081185071866,
#    'num_acts': 54,
#    'tp_ratio': -0.03862068965517243}),
#  ('Request-Attraction-Price',
#   {'fn_ratio': 0.07421150278293132,
#    'fp_ratio': -0.036105812763986056,
#    'num_acts': 35,
#    'tp_ratio': -0.039215686274509776}),
#  ('Inform-Hotel-Parking',
#   {'fn_ratio': 0.04591155188985468,
#    'fp_ratio': -0.005747206097157592,
#    'num_acts': 307,
#    'tp_ratio': -0.040361599185128605}),
#  ('NoBook-Booking-none',
#   {'fn_ratio': 0.01592852771647786,
#    'fp_ratio': 0.024688371369718964,
#    'num_acts': 223,
#    'tp_ratio': -0.040868865647626706}),
#  ('OfferBooked-Train-Id',
#   {'fn_ratio': 0.07504466697035561,
#    'fp_ratio': -0.03345482630928048,
#    'num_acts': 151,
#    'tp_ratio': -0.041418041418041396}),
#  ('Request-Hotel-Name',
#   {'fn_ratio': -0.1000051232132794,
#    'fp_ratio': 0.1500485171883097,
#    'num_acts': 28,
#    'tp_ratio': -0.041666666666666685}),
#  ('Request-Booking-Stay',
#   {'fn_ratio': 0.03507493823129017,
#    'fp_ratio': 0.008533951451346146,
#    'num_acts': 221,
#    'tp_ratio': -0.043898443898443884}),
#  ('Recommend-Restaurant-Addr',
#   {'fn_ratio': -0.08076715289032965,
#    'fp_ratio': 0.1286698234510894,
#    'num_acts': 97,
#    'tp_ratio': -0.046511627906976744}),
#  ('Book-Booking-Day',
#   {'fn_ratio': 0.0568428472857653,
#    'fp_ratio': -0.010391962643544271,
#    'num_acts': 179,
#    'tp_ratio': -0.04681647940074907}),
#  ('OfferBook-Train-Arrive',
#   {'fn_ratio': 0.04869105134674112,
#    'fp_ratio': -1.835213716322448e-05,
#    'num_acts': 42,
#    'tp_ratio': -0.047619047619047616}),
#  ('Inform-Booking-Stay',
#   {'fn_ratio': -0.0619195046439629,
#    'fp_ratio': 0.11291811101607166,
#    'num_acts': 13,
#    'tp_ratio': -0.047619047619047616}),
#  ('Select-Restaurant-Area',
#   {'fn_ratio': -0.09269162210338677,
#    'fp_ratio': 0.14867000208396686,
#    'num_acts': 18,
#    'tp_ratio': -0.04999999999999999}),
#  ('Inform-Train-Dest',
#   {'fn_ratio': 0.05527255052371688,
#    'fp_ratio': 0.012598570831778871,
#    'num_acts': 516,
#    'tp_ratio': -0.06784855769230769}),
#  ('Recommend-Hotel-Addr',
#   {'fn_ratio': -0.13959390862944165,
#    'fp_ratio': 0.21589991662123015,
#    'num_acts': 34,
#    'tp_ratio': -0.07142857142857142}),
#  ('NoOffer-Restaurant-none',
#   {'fn_ratio': 0.05100916144895512,
#    'fp_ratio': 0.02879541090612031,
#    'num_acts': 136,
#    'tp_ratio': -0.07965367965367964}),
#  ('NoBook-Booking-People',
#   {'fn_ratio': 0.14796238244514115,
#    'fp_ratio': -0.060075848172772506,
#    'num_acts': 23,
#    'tp_ratio': -0.08333333333333333}),
#  ('Book-Booking-none',
#   {'fn_ratio': 0.08380192272809717,
#    'fp_ratio': -5.702620657715984e-06,
#    'num_acts': 24,
#    'tp_ratio': -0.08333333333333337}),
#  ('Inform-Train-Time',
#   {'fn_ratio': 0.0305090958994505,
#    'fp_ratio': 0.05672227278650083,
#    'num_acts': 329,
#    'tp_ratio': -0.08720112517580869}),
#  ('NoOffer-Hotel-Stars',
#   {'fn_ratio': 0.0170109754577481,
#    'fp_ratio': 0.08197569064331922,
#    'num_acts': 47,
#    'tp_ratio': -0.09636363636363635}),
#  ('Select-Hotel-Area',
#   {'fn_ratio': -0.07691871406842149,
#    'fp_ratio': 0.18260438785230132,
#    'num_acts': 50,
#    'tp_ratio': -0.1038961038961039}),
#  ('NoOffer-Hotel-Area',
#   {'fn_ratio': 0.22100068284809726,
#    'fp_ratio': -0.07860328877001224,
#    'num_acts': 40,
#    'tp_ratio': -0.13784461152882205}),
#  ('OfferBooked-Train-Time',
#   {'fn_ratio': 0.5800000000000001,
#    'fp_ratio': -0.3966754816773706,
#    'num_acts': 11,
#    'tp_ratio': -0.14285714285714285}),
#  ('NoBook-Booking-Day',
#   {'fn_ratio': 0.03584705257567711,
#    'fp_ratio': 0.10592686002522067,
#    'num_acts': 34,
#    'tp_ratio': -0.14583333333333337}),
#  ('Inform-Taxi-Dest',
#   {'fn_ratio': 0.19187785524737744,
#    'fp_ratio': -0.025097485550026943,
#    'num_acts': 59,
#    'tp_ratio': -0.16436781609195403}),
#  ('NoOffer-Hotel-Parking',
#   {'fn_ratio': 0.2222222222222222,
#    'fp_ratio': 0.0012383900928792657,
#    'num_acts': 8,
#    'tp_ratio': -0.25}),
#  ('Select-Train-Arrive',
#   {'fn_ratio': 0.27941176470588236,
#    'fp_ratio': -0.0013116904410559183,
#    'num_acts': 8,
#    'tp_ratio': -0.25}),
#  ('OfferBooked-Train-Depart',
#   {'fn_ratio': 0.1867441881658207,
#    'fp_ratio': 0.08503054116391617,
#    'num_acts': 36,
#    'tp_ratio': -0.27244582043343657}),
#  ('NoOffer-Train-Depart',
#   {'fn_ratio': 0.19786096256684488,
#    'fp_ratio': 0.2118380062305296,
#    'num_acts': 7,
#    'tp_ratio': -0.41666666666666663})]

# %%
ppo_win_turns = search_ppo_win_turns(ids='Request-Taxi-Leave',
                                     result_gpt2=result_gpt2_bert_0,
                                     result_ppo=result_ppo_bert_0,
                                     is_win_wer=True)
pprint(ppo_win_turns)
# Out:
# [{'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time do you like to leave arrive by?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like to leave the restaurant or '
#                          'arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Booking-Time-?'],
#            'gen_text': 'What time would you like to leave?',
#            'noised_text': 'What time would like to Ruby.',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'What time would you like to be picked up?',
#           'noised_text': 'What time would you like to be picked up?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Arrive-?', 'Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time would you like to leave you arrive by?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like to leave the restaurant Dean '
#                          'arrive by?',
#           'tp_acts': ['Request-Taxi-Arrive-?', 'Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Depart-?',
#              'Request-Taxi-Leave-?',
#              'greet-general-none-none'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Depart-?',
#                        'Request-Taxi-Leave-?',
#                        'greet-general-none-none'],
#            'fp_acts': ['Request-Train-Depart-?', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. Where will you be departing '
#                        'from and what time would you like to leave?',
#            'noised_text': 'I can you with that. There will you departing from '
#                           'and what time would you to.',
#            'tp_acts': []},
#   'ppo': {'fn_acts': ['greet-general-none-none'],
#           'fp_acts': ['Request-Taxi-Dest-?', 'Request-Taxi-Arrive-?'],
#           'gen_text': 'Sure! Where would you like to be picked up and at what '
#                       'time?',
#           'noised_text': '. Where would you like to be up and at what time.',
#           'tp_acts': ['Request-Taxi-Depart-?', 'Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?',
#              'Request-Taxi-Arrive-?',
#              'greet-general-none-none'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'greet-general-none-none'],
#            'fp_acts': ['Request-Train-Arrive-?'],
#            'gen_text': 'I can help with that. What time would you like to '
#                        'leave or arrive by?',
#            'noised_text': 'help with that? Type time would you like to believe '
#                           'or arrive I?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': ['greet-general-none-none'],
#           'fp_acts': [],
#           'gen_text': 'Sure! What time do you need to leave the restaurant or '
#                       'arrive by?',
#           'noised_text': '. What time do you to leave the restaurant or arrive '
#                          'by internet',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time would you like to leave for arrive by?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like to leave the restaurant or ride '
#                          'by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'time would me like to leave for arrive by.',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like to leave the restaurant your '
#                          'arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Depart-?', 'Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Depart-?', 'Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Depart-?', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. What time would you like to '
#                        'leave and where are you departing from?',
#            'noised_text': 'I help you with that, What time would you like to '
#                           'leave and where are you departing?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Arrive-?'],
#           'gen_text': 'Where would you like to be picked up and at what time?',
#           'noised_text': 'Where would you like to picked number and at what '
#                          'time?',
#           'tp_acts': ['Request-Taxi-Depart-?', 'Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'time do you like to leave or arrive by?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like leave the restaurant or arrive '
#                          'by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Depart-?',
#              'Request-Taxi-Dest-?',
#              'Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Depart-?',
#                        'Request-Taxi-Dest-?',
#                        'Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Depart-?',
#                        'Request-Train-Dest-?',
#                        'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. What is your departure site '
#                        'and destination? And what time would you like to leave '
#                        'or arrive?',
#            'noised_text': 'I can help you with that Z. is your departure I and '
#                           'destination And what time you like to leave or '
#                           'ride?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Arrive-?'],
#           'gen_text': 'Where would you like to be picked up and where would '
#                       'you like to be to and at what time?',
#           'noised_text': 'Where would for like to be picked up and where would '
#                          'you like be to and at what time',
#           'tp_acts': ['Request-Taxi-Depart-?',
#                       'Request-Taxi-Dest-?',
#                       'Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#            'fp_acts': ['Request-Train-Dest-?', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I help you with that. What is your destination in '
#                           'what time would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Depart-?', 'Request-Taxi-Arrive-?'],
#           'gen_text': 'What time would you like to be picked up and what is '
#                       'your destination?',
#           'noised_text': 'What time would you like to be picked up and what is '
#                          'your destination?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?']}},
#  {'action': ['Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Leave-?'],
#            'gen_text': 'What time would you like to leave?',
#            'noised_text': 'Price time with you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Arrive-?'],
#           'gen_text': 'What time would you like to be picked up?',
#           'noised_text': 'What time would you like to be picked?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#            'fp_acts': ['Request-Train-Dest-?', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I can help you with that. pretty your destination '
#                           'and what time would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Depart-?'],
#           'gen_text': 'What time would you like to be picked up and what is '
#                       'your destination?',
#           'noised_text': 'What anytime would you like to be picked up and what '
#                          'is your destination?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Depart-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Depart-?'],
#            'fp_acts': ['Request-Train-Depart-?', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. Where are you departing from '
#                        'and what time would you like to leave?',
#            'noised_text': 'I can is you will that a Where are you departing '
#                           'from in what time would you like can leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'Where would you like to be picked up and at what time?',
#           'noised_text': 'Where would you like to be picked up and at what '
#                          'time?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Depart-?']}},
#  {'action': ['Request-Taxi-Leave-?',
#              'Inform-Attraction-Phone-01223338300',
#              "Inform-Attraction-Addr-King 's Parade",
#              'Inform-Attraction-Post-CB21RL'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?',
#                        'Inform-Attraction-Phone-01223338300',
#                        "Inform-Attraction-Addr-King 's Parade",
#                        'Inform-Attraction-Post-CB21RL'],
#            'fp_acts': ['Request-Train-Leave-?',
#                        'Inform-Attraction-Addr-King Halls',
#                        'Inform-Restaurant-Post-CB21RL',
#                        'Inform-Attraction-Fee-0'],
#            'gen_text': "The address is King's Parade, CB21RL. The phone number "
#                        'is 01223338300. What time would you like to leave?',
#            'noised_text': 'The address is King Halls Parade East CB21RL 2 '
#                           'Surprise phone number is 0. What time would you '
#                           'like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': ['Inform-Attraction-Phone-01223338300'],
#           'fp_acts': ['Inform-Attraction-Phone-8300'],
#           'gen_text': "The address is King's Parade, postcode CB21RL. The "
#                       'phone number is 01223338300. What time would you like '
#                       'to be picked up?',
#           'noised_text': "The address is King's Parade. postcode CB21RL, The "
#                          'phone number is 8300 What time would you like to be '
#                          'picked up?',
#           'tp_acts': ['Request-Taxi-Leave-?',
#                       "Inform-Attraction-Addr-King 's Parade",
#                       'Inform-Attraction-Post-CB21RL']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time would you like to leave are arrive by?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'When would you like to leave the restaurant or '
#                          'arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?',
#              'Request-Taxi-Dest-?',
#              'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#            'fp_acts': [],
#            'gen_text': 'I can help with that. What is your destination and '
#                        'what time would you like to leave or arrive by?',
#            'noised_text': 'I can with that? What is your destination and what '
#                           'would you like to Glue the life by?',
#            'tp_acts': ['Request-Taxi-Dest-?']},
#   'ppo': {'fn_acts': ['Request-Taxi-Dest-?'],
#           'fp_acts': [],
#           'gen_text': 'When would you like to leave the restaurant or arrive '
#                       'by?',
#           'noised_text': 'would you like to leave the restaurant or arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#            'fp_acts': ['greet-general-none-none', 'Request-Train-Leave-?'],
#            'gen_text': 'I can help you with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I can help you with that.? gets your destination. '
#                           'time would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Arrive-?'],
#           'gen_text': 'What time would you like to be picked up and what is '
#                       'your destination?',
#           'noised_text': 'What time would you like to be picked Another and '
#                          'what is your destination?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?']}}]

# %%
result_gpt2_milu_0 = get_result("baselines", "gpt2-checkpoints-milu-full-sys-background(0)")
acc_by_da_gpt2_milu_0 = compute_acc_by_da(result_gpt2_milu_0)

result_ppo_milu_0 = get_result("ppo", "milu-full-sys-noise-background(0)-seed12")
acc_by_da_ppo_milu_0 = compute_acc_by_da(result_ppo_milu_0)

diff_gpt2_ppo_milu_0 = compute_diff(acc_by_da_gpt2_milu_0, acc_by_da_ppo_milu_0)

pprint(sorted(diff_gpt2_ppo_milu_0.items(), key=lambda x: x[1]['tp_ratio'], reverse=True))
# Out:
# 100%|██████████| 7372/7372 [00:00<00:00, 456902.34it/s]
# 100%|██████████| 7372/7372 [00:00<00:00, 523755.15it/s]
# [('Inform-Police-Name',
#   {'fn_ratio': -1.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 1.0}),
#  ('NoOffer-Train-Day',
#   {'fn_ratio': -0.2666666666666666,
#    'fp_ratio': -0.27272727272727276,
#    'num_acts': 5,
#    'tp_ratio': 0.5}),
#  ('Request-Hotel-Name',
#   {'fn_ratio': 0.1288244766505636,
#    'fp_ratio': -0.5173383317713215,
#    'num_acts': 22,
#    'tp_ratio': 0.380952380952381}),
#  ('Request-Restaurant-Name',
#   {'fn_ratio': -0.06428571428571428,
#    'fp_ratio': -0.27225335195019784,
#    'num_acts': 15,
#    'tp_ratio': 0.3333333333333333}),
#  ('Select-Hotel-none',
#   {'fn_ratio': 0.10954026644787274,
#    'fp_ratio': -0.39876218881511244,
#    'num_acts': 132,
#    'tp_ratio': 0.2876813375952791}),
#  ('Recommend-Hotel-Parking',
#   {'fn_ratio': -0.28180619644034277,
#    'fp_ratio': 0.0,
#    'num_acts': 36,
#    'tp_ratio': 0.2777777777777778}),
#  ('Request-Train-Dest',
#   {'fn_ratio': -0.020973774567965675,
#    'fp_ratio': -0.19421886581931327,
#    'num_acts': 409,
#    'tp_ratio': 0.21549384511001257}),
#  ('Request-Taxi-Leave',
#   {'fn_ratio': 0.08090773578639775,
#    'fp_ratio': -0.28813488586584834,
#    'num_acts': 249,
#    'tp_ratio': 0.2066666666666666}),
#  ('Recommend-Restaurant-Food',
#   {'fn_ratio': -0.27178464317558104,
#    'fp_ratio': 0.06898449538981646,
#    'num_acts': 86,
#    'tp_ratio': 0.202710027100271}),
#  ('OfferBook-Train-Depart',
#   {'fn_ratio': -0.6153846153846154,
#    'fp_ratio': 0.3581267217630854,
#    'num_acts': 8,
#    'tp_ratio': 0.2}),
#  ('Recommend-Restaurant-Price',
#   {'fn_ratio': -0.22566667161321913,
#    'fp_ratio': 0.0256683461479979,
#    'num_acts': 57,
#    'tp_ratio': 0.19950738916256158}),
#  ('Inform-Hotel-Price',
#   {'fn_ratio': 0.06488922652342144,
#    'fp_ratio': -0.24929135282626566,
#    'num_acts': 679,
#    'tp_ratio': 0.18410807513590127}),
#  ('Recommend-Attraction-Fee',
#   {'fn_ratio': -0.24547878152178665,
#    'fp_ratio': 0.06467122977846712,
#    'num_acts': 107,
#    'tp_ratio': 0.18067226890756302}),
#  ('NoOffer-Hotel-none',
#   {'fn_ratio': -0.2388698630136986,
#    'fp_ratio': 0.0528468909987752,
#    'num_acts': 33,
#    'tp_ratio': 0.17647058823529413}),
#  ('NoOffer-Restaurant-none',
#   {'fn_ratio': -0.03801375950024055,
#    'fp_ratio': -0.1378230806752207,
#    'num_acts': 108,
#    'tp_ratio': 0.175}),
#  ('Recommend-Hotel-Price',
#   {'fn_ratio': -0.1734943563027863,
#    'fp_ratio': 6.418004120420373e-06,
#    'num_acts': 70,
#    'tp_ratio': 0.17142857142857143}),
#  ('Request-Taxi-Arrive',
#   {'fn_ratio': 0.09549384333246005,
#    'fp_ratio': -0.2679176879758908,
#    'num_acts': 119,
#    'tp_ratio': 0.17142857142857137}),
#  ('Request-Train-Depart',
#   {'fn_ratio': 0.017689009146909462,
#    'fp_ratio': -0.18816036449425677,
#    'num_acts': 462,
#    'tp_ratio': 0.1707751820388349}),
#  ('Recommend-Hotel-Internet',
#   {'fn_ratio': -0.12513452432199745,
#    'fp_ratio': -0.045565905296317745,
#    'num_acts': 39,
#    'tp_ratio': 0.16842105263157892}),
#  ('OfferBook-Train-Arrive',
#   {'fn_ratio': -0.09954128440366983,
#    'fp_ratio': -0.07184801286036513,
#    'num_acts': 38,
#    'tp_ratio': 0.16666666666666666}),
#  ('Request-Hotel-Area',
#   {'fn_ratio': -0.08562015571267251,
#    'fp_ratio': -0.07472895686125705,
#    'num_acts': 423,
#    'tp_ratio': 0.1607230858832489}),
#  ('Inform-Booking-Stay',
#   {'fn_ratio': 0.0029806259314456574,
#    'fp_ratio': -0.17566090110828925,
#    'num_acts': 19,
#    'tp_ratio': 0.1590909090909091}),
#  ('OfferBook-Train-none',
#   {'fn_ratio': -0.10914763103381633,
#    'fp_ratio': -0.037398569381822504,
#    'num_acts': 718,
#    'tp_ratio': 0.1467182066567312}),
#  ('Request-Attraction-Type',
#   {'fn_ratio': -0.12685337275364733,
#    'fp_ratio': -1.4718841022109963e-06,
#    'num_acts': 204,
#    'tp_ratio': 0.12745098039215685}),
#  ('Request-Hotel-Price',
#   {'fn_ratio': -0.009953345583459582,
#    'fp_ratio': -0.11200991961280776,
#    'num_acts': 316,
#    'tp_ratio': 0.1220789685737308}),
#  ('Select-Attraction-none',
#   {'fn_ratio': -0.19826551398016345,
#    'fp_ratio': 0.083073879072407,
#    'num_acts': 63,
#    'tp_ratio': 0.11212121212121212}),
#  ('NoOffer-Hotel-Type',
#   {'fn_ratio': -0.03432267910305081,
#    'fp_ratio': -0.07804715204617474,
#    'num_acts': 117,
#    'tp_ratio': 0.11143695014662755}),
#  ('Select-Hotel-Area',
#   {'fn_ratio': -0.18805688470242427,
#    'fp_ratio': 0.07659791908449835,
#    'num_acts': 44,
#    'tp_ratio': 0.10973084886128365}),
#  ('NoOffer-Attraction-Area',
#   {'fn_ratio': -0.001099210085465041,
#    'fp_ratio': -0.10722216469633261,
#    'num_acts': 118,
#    'tp_ratio': 0.10706018518518517}),
#  ('Select-Hotel-Type',
#   {'fn_ratio': -0.06928705028055882,
#    'fp_ratio': -0.036142326989189955,
#    'num_acts': 43,
#    'tp_ratio': 0.10389610389610388}),
#  ('Request-Restaurant-Price',
#   {'fn_ratio': 0.032993367057856854,
#    'fp_ratio': -0.13495123105574275,
#    'num_acts': 288,
#    'tp_ratio': 0.10153078691250556}),
#  ('Request-Train-Leave',
#   {'fn_ratio': 0.04759074723649388,
#    'fp_ratio': -0.14901097852508152,
#    'num_acts': 572,
#    'tp_ratio': 0.10139760938482989}),
#  ('Book-Booking-none',
#   {'fn_ratio': -0.10677538342069492,
#    'fp_ratio': 0.0,
#    'num_acts': 20,
#    'tp_ratio': 0.1}),
#  ('Request-Restaurant-Area',
#   {'fn_ratio': 0.00924575674014308,
#    'fp_ratio': -0.10633558060233317,
#    'num_acts': 254,
#    'tp_ratio': 0.09708374875373871}),
#  ('OfferBook-Train-Id',
#   {'fn_ratio': 0.012256309222253514,
#    'fp_ratio': -0.11020254979826233,
#    'num_acts': 68,
#    'tp_ratio': 0.09590235396687008}),
#  ('NoOffer-Attraction-none',
#   {'fn_ratio': 0.04019191989430504,
#    'fp_ratio': -0.13465153179543513,
#    'num_acts': 26,
#    'tp_ratio': 0.09523809523809523}),
#  ('Book-Booking-Day',
#   {'fn_ratio': -0.10533400503636947,
#    'fp_ratio': 0.011109561212176964,
#    'num_acts': 173,
#    'tp_ratio': 0.09489441325848702}),
#  ('Book-Booking-Ref',
#   {'fn_ratio': -0.05208898986120589,
#    'fp_ratio': -0.04065361309529264,
#    'num_acts': 1602,
#    'tp_ratio': 0.09273471935093813}),
#  ('Request-Hotel-Internet',
#   {'fn_ratio': -0.027019258407588398,
#    'fp_ratio': -0.06374724551153987,
#    'num_acts': 46,
#    'tp_ratio': 0.09090909090909094}),
#  ('Select-Restaurant-Food',
#   {'fn_ratio': 0.10552473115735428,
#    'fp_ratio': -0.19752943861767042,
#    'num_acts': 61,
#    'tp_ratio': 0.08901098901098903}),
#  ('Inform-Booking-none',
#   {'fn_ratio': -0.05716480347258711,
#    'fp_ratio': -0.026075385341528826,
#    'num_acts': 1128,
#    'tp_ratio': 0.08333752578356901}),
#  ('OfferBook-Train-Day',
#   {'fn_ratio': 0.12941176470588234,
#    'fp_ratio': -0.2118380062305296,
#    'num_acts': 7,
#    'tp_ratio': 0.08333333333333331}),
#  ('Request-Hotel-Parking',
#   {'fn_ratio': -0.02492784992784991,
#    'fp_ratio': -0.056968619328661096,
#    'num_acts': 54,
#    'tp_ratio': 0.08241758241758246}),
#  ('Request-Attraction-Price',
#   {'fn_ratio': 0.20762883028449425,
#    'fp_ratio': -0.29346316909419046,
#    'num_acts': 33,
#    'tp_ratio': 0.08076923076923079}),
#  ('Request-Train-People',
#   {'fn_ratio': -0.0557136454131357,
#    'fp_ratio': -0.022982300312215976,
#    'num_acts': 166,
#    'tp_ratio': 0.07926829268292679}),
#  ('NoOffer-Restaurant-Area',
#   {'fn_ratio': -0.01952898191551128,
#    'fp_ratio': -0.059964432213782115,
#    'num_acts': 122,
#    'tp_ratio': 0.07866379310344829}),
#  ('Inform-Taxi-Phone',
#   {'fn_ratio': -0.029923677360099737,
#    'fp_ratio': -0.04788405344463431,
#    'num_acts': 565,
#    'tp_ratio': 0.07786391690501271}),
#  ('Inform-Hotel-Internet',
#   {'fn_ratio': -0.09023260214384748,
#    'fp_ratio': 0.016953623623405606,
#    'num_acts': 358,
#    'tp_ratio': 0.07338389986578026}),
#  ('Inform-Booking-Day',
#   {'fn_ratio': -0.023568925233644844,
#    'fp_ratio': -0.05042015981393422,
#    'num_acts': 44,
#    'tp_ratio': 0.07246376811594202}),
#  ('Recommend-Hotel-Addr',
#   {'fn_ratio': -0.0023375074537864693,
#    'fp_ratio': -0.07018705724794988,
#    'num_acts': 34,
#    'tp_ratio': 0.06944444444444445}),
#  ('Inform-Taxi-Arrive',
#   {'fn_ratio': -0.14401858304297332,
#    'fp_ratio': 0.07193592882149184,
#    'num_acts': 23,
#    'tp_ratio': 0.06818181818181818}),
#  ('Inform-Hotel-Choice',
#   {'fn_ratio': 0.05377838595752649,
#    'fp_ratio': -0.12191793322655742,
#    'num_acts': 1101,
#    'tp_ratio': 0.06804168966870416}),
#  ('Recommend-Attraction-Area',
#   {'fn_ratio': -0.12860475790864917,
#    'fp_ratio': 0.06262535410942013,
#    'num_acts': 73,
#    'tp_ratio': 0.06541353383458645}),
#  ('Request-Taxi-Dest',
#   {'fn_ratio': -0.22259945277270593,
#    'fp_ratio': 0.16618277035080575,
#    'num_acts': 187,
#    'tp_ratio': 0.05776846028418359}),
#  ('OfferBooked-Train-Depart',
#   {'fn_ratio': 0.03833515881708649,
#    'fp_ratio': -0.09451052531714561,
#    'num_acts': 34,
#    'tp_ratio': 0.05555555555555558}),
#  ('OfferBook-Train-Leave',
#   {'fn_ratio': 0.06461535132952057,
#    'fp_ratio': -0.12123608149608517,
#    'num_acts': 46,
#    'tp_ratio': 0.05523809523809523}),
#  ('reqmore-general-none',
#   {'fn_ratio': -0.007878175731396805,
#    'fp_ratio': -0.046594628309542585,
#    'num_acts': 3003,
#    'tp_ratio': 0.05450010429750085}),
#  ('OfferBooked-Train-Arrive',
#   {'fn_ratio': -0.023806888409246052,
#    'fp_ratio': -0.028948380770624865,
#    'num_acts': 51,
#    'tp_ratio': 0.05230769230769228}),
#  ('Request-Booking-Stay',
#   {'fn_ratio': 0.05701030244570626,
#    'fp_ratio': -0.10750043949547232,
#    'num_acts': 250,
#    'tp_ratio': 0.05051089261615571}),
#  ('Inform-Taxi-Dest',
#   {'fn_ratio': 0.08086929782050745,
#    'fp_ratio': -0.13068511276181127,
#    'num_acts': 74,
#    'tp_ratio': 0.04804138950480415}),
#  ('OfferBooked-Train-Leave',
#   {'fn_ratio': -0.032841712126908895,
#    'fp_ratio': -0.01495552645648951,
#    'num_acts': 91,
#    'tp_ratio': 0.047342995169082136}),
#  ('Recommend-Restaurant-Area',
#   {'fn_ratio': -0.06203935413212258,
#    'fp_ratio': 0.015513070715086286,
#    'num_acts': 85,
#    'tp_ratio': 0.04595791805094131}),
#  ('Inform-Train-Ref',
#   {'fn_ratio': -0.08149239077074133,
#    'fp_ratio': 0.03425703112588477,
#    'num_acts': 43,
#    'tp_ratio': 0.045454545454545456}),
#  ('Recommend-Restaurant-Name',
#   {'fn_ratio': -0.06599704285206603,
#    'fp_ratio': 0.02159547337813955,
#    'num_acts': 497,
#    'tp_ratio': 0.04436920883820385}),
#  ('OfferBook-Train-Dest',
#   {'fn_ratio': -0.21095421480530593,
#    'fp_ratio': 0.1789794775547059,
#    'num_acts': 22,
#    'tp_ratio': 0.04273504273504275}),
#  ('Select-Restaurant-none',
#   {'fn_ratio': 0.02252126603239679,
#    'fp_ratio': -0.06512405995188576,
#    'num_acts': 108,
#    'tp_ratio': 0.0425824175824176}),
#  ('Recommend-Hotel-Name',
#   {'fn_ratio': -0.08787893951241843,
#    'fp_ratio': 0.04748573560561209,
#    'num_acts': 445,
#    'tp_ratio': 0.040397297406643204}),
#  ('OfferBooked-Train-Id',
#   {'fn_ratio': -0.014366728537679174,
#    'fp_ratio': -0.022409093959047388,
#    'num_acts': 214,
#    'tp_ratio': 0.03660987330712101}),
#  ('Inform-Restaurant-Food',
#   {'fn_ratio': 0.020696756118500026,
#    'fp_ratio': -0.05618678099177224,
#    'num_acts': 790,
#    'tp_ratio': 0.03546836596525682}),
#  ('Inform-Attraction-Area',
#   {'fn_ratio': -0.019937216362699295,
#    'fp_ratio': -0.015256471699514162,
#    'num_acts': 962,
#    'tp_ratio': 0.03515832702907165}),
#  ('Request-Taxi-Depart',
#   {'fn_ratio': -0.10608736663843212,
#    'fp_ratio': 0.07522719592532612,
#    'num_acts': 294,
#    'tp_ratio': 0.03144654088050314}),
#  ('OfferBooked-Train-Ref',
#   {'fn_ratio': -0.07886852631715835,
#    'fp_ratio': 0.04987031334097794,
#    'num_acts': 664,
#    'tp_ratio': 0.028985507246376774}),
#  ('Inform-Restaurant-Addr',
#   {'fn_ratio': 0.004741362813686201,
#    'fp_ratio': -0.033772393179544724,
#    'num_acts': 674,
#    'tp_ratio': 0.02892416225749559}),
#  ('NoBook-Booking-Time',
#   {'fn_ratio': 0.05994371482176364,
#    'fp_ratio': -0.08861876507562028,
#    'num_acts': 34,
#    'tp_ratio': 0.02777777777777779}),
#  ('Inform-Train-Depart',
#   {'fn_ratio': -0.007270603000504472,
#    'fp_ratio': -0.01901967433873175,
#    'num_acts': 437,
#    'tp_ratio': 0.02626948215183511}),
#  ('Recommend-Hotel-Area',
#   {'fn_ratio': -0.24080462209645093,
#    'fp_ratio': 0.21408091121389622,
#    'num_acts': 85,
#    'tp_ratio': 0.02533783783783783}),
#  ('Recommend-Hotel-Stars',
#   {'fn_ratio': 0.04411657296250371,
#    'fp_ratio': -0.06964071655437715,
#    'num_acts': 93,
#    'tp_ratio': 0.025046382189239335}),
#  ('Inform-Booking-Name',
#   {'fn_ratio': 0.009171184801178622,
#    'fp_ratio': -0.03299082159892852,
#    'num_acts': 119,
#    'tp_ratio': 0.023203169213355967}),
#  ('Inform-Attraction-Name',
#   {'fn_ratio': 0.021032900423087808,
#    'fp_ratio': -0.04421149477827124,
#    'num_acts': 1151,
#    'tp_ratio': 0.023142494407835085}),
#  ('Book-Booking-Name',
#   {'fn_ratio': 0.008704080989339835,
#    'fp_ratio': -0.031175436353624075,
#    'num_acts': 452,
#    'tp_ratio': 0.022315913324835776}),
#  ('Inform-Restaurant-Area',
#   {'fn_ratio': 0.021457142970934873,
#    'fp_ratio': -0.0430806820149266,
#    'num_acts': 907,
#    'tp_ratio': 0.0215638541311651}),
#  ('Inform-Train-Dest',
#   {'fn_ratio': -0.02755211283108505,
#    'fp_ratio': 0.006600761387475812,
#    'num_acts': 504,
#    'tp_ratio': 0.020943892414531595}),
#  ('OfferBooked-Train-People',
#   {'fn_ratio': 0.11062768023418068,
#    'fp_ratio': -0.13091701866804883,
#    'num_acts': 162,
#    'tp_ratio': 0.01944444444444446}),
#  ('Book-Booking-Time',
#   {'fn_ratio': 0.0835810914512487,
#    'fp_ratio': -0.1010285276103696,
#    'num_acts': 167,
#    'tp_ratio': 0.0174301354076635}),
#  ('Recommend-Attraction-Type',
#   {'fn_ratio': 0.057746656275338704,
#    'fp_ratio': -0.07538584557250869,
#    'num_acts': 59,
#    'tp_ratio': 0.01728110599078342}),
#  ('Inform-Attraction-Fee',
#   {'fn_ratio': 0.028595144973558695,
#    'fp_ratio': -0.04486215831855339,
#    'num_acts': 735,
#    'tp_ratio': 0.016192891142844418}),
#  ('Inform-Train-Leave',
#   {'fn_ratio': -0.012554403288389637,
#    'fp_ratio': -0.0032226347765130225,
#    'num_acts': 1327,
#    'tp_ratio': 0.01576675828544169}),
#  ('Recommend-Attraction-Name',
#   {'fn_ratio': -0.009568399674094896,
#    'fp_ratio': -0.005812941840560859,
#    'num_acts': 555,
#    'tp_ratio': 0.015349851955742566}),
#  ('Inform-Hotel-Name',
#   {'fn_ratio': 0.02471302847171447,
#    'fp_ratio': -0.039259553283285176,
#    'num_acts': 1266,
#    'tp_ratio': 0.014511003178029627}),
#  ('NoOffer-Attraction-Type',
#   {'fn_ratio': 0.040424875645786396,
#    'fp_ratio': -0.05402326215463016,
#    'num_acts': 106,
#    'tp_ratio': 0.01319073083778971}),
#  ('Inform-Attraction-Choice',
#   {'fn_ratio': -0.037620594622910064,
#    'fp_ratio': 0.02665655341522169,
#    'num_acts': 637,
#    'tp_ratio': 0.01097503254052773}),
#  ('Inform-Train-Choice',
#   {'fn_ratio': -0.03511894722642833,
#    'fp_ratio': 0.026221241869301054,
#    'num_acts': 708,
#    'tp_ratio': 0.008908045977011503}),
#  ('Inform-Train-Arrive',
#   {'fn_ratio': 0.001659892428136911,
#    'fp_ratio': -0.009632157341338099,
#    'num_acts': 1055,
#    'tp_ratio': 0.007964232831615403}),
#  ('Inform-Hotel-Stars',
#   {'fn_ratio': 0.04613150321144471,
#    'fp_ratio': -0.05333933569627114,
#    'num_acts': 591,
#    'tp_ratio': 0.0071266267300144626}),
#  ('Request-Train-Arrive',
#   {'fn_ratio': 0.009726875914139566,
#    'fp_ratio': -0.01651059471103511,
#    'num_acts': 316,
#    'tp_ratio': 0.006730769230769318}),
#  ('Request-Attraction-Area',
#   {'fn_ratio': -0.049198236299316384,
#    'fp_ratio': 0.043120380801290825,
#    'num_acts': 191,
#    'tp_ratio': 0.006254114549045453}),
#  ('Inform-Restaurant-Name',
#   {'fn_ratio': 0.012861503724981516,
#    'fp_ratio': -0.019116196729174362,
#    'num_acts': 1315,
#    'tp_ratio': 0.006235914238246626}),
#  ('Inform-Restaurant-Post',
#   {'fn_ratio': 0.0053288910679960555,
#    'fp_ratio': -0.01113801198184955,
#    'num_acts': 366,
#    'tp_ratio': 0.005763774824548304}),
#  ('Inform-Restaurant-Phone',
#   {'fn_ratio': 0.033805574224709645,
#    'fp_ratio': -0.03860907024840565,
#    'num_acts': 548,
#    'tp_ratio': 0.004662596358098087}),
#  ('Inform-Hotel-Type',
#   {'fn_ratio': 0.11543000263565079,
#    'fp_ratio': -0.11955902465581209,
#    'num_acts': 984,
#    'tp_ratio': 0.004019094869817191}),
#  ('Inform-Attraction-Post',
#   {'fn_ratio': -0.021034395239678094,
#    'fp_ratio': 0.01728035506678416,
#    'num_acts': 504,
#    'tp_ratio': 0.003732577368296717}),
#  ('Inform-Restaurant-Choice',
#   {'fn_ratio': -0.014634206340298384,
#    'fp_ratio': 0.012784639168964995,
#    'num_acts': 987,
#    'tp_ratio': 0.0018602015423657692}),
#  ('Inform-Train-Ticket',
#   {'fn_ratio': -0.03562959456474912,
#    'fp_ratio': 0.03499759807410607,
#    'num_acts': 526,
#    'tp_ratio': 0.0006801244483033084}),
#  ('NoOffer-Restaurant-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('OfferBooked-Train-Ticket',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 602, 'tp_ratio': 0.0}),
#  ('Inform-Booking-Time',
#   {'fn_ratio': 0.15000000000000002,
#    'fp_ratio': -0.14661654135338348,
#    'num_acts': 9,
#    'tp_ratio': 0.0}),
#  ('greet-general-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 468, 'tp_ratio': 0.0}),
#  ('Inform-Train-People',
#   {'fn_ratio': 0.16666666666666663,
#    'fp_ratio': -0.17171717171717166,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('Inform-Hotel-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('Inform-Hotel-Phone',
#   {'fn_ratio': 0.05822429906542059,
#    'fp_ratio': -0.05789704082959629,
#    'num_acts': 207,
#    'tp_ratio': 0.0}),
#  ('NoOffer-Attraction-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-Day',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 36, 'tp_ratio': 0.0}),
#  ('Inform-Restaurant-Ref',
#   {'fn_ratio': 0.04999999999999999,
#    'fp_ratio': -0.05291005291005302,
#    'num_acts': 45,
#    'tp_ratio': 0.0}),
#  ('Select-Attraction-Type',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 116, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-People',
#   {'fn_ratio': 0.13333333333333341,
#    'fp_ratio': -0.1306042884990254,
#    'num_acts': 22,
#    'tp_ratio': 0.0}),
#  ('Select-Train-Leave',
#   {'fn_ratio': -0.09722222222222221,
#    'fp_ratio': 0.09186939820742636,
#    'num_acts': 17,
#    'tp_ratio': 0.0}),
#  ('OfferBook-Train-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('OfferBook-Train-People',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 12, 'tp_ratio': 0.0}),
#  ('Recommend-Hotel-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Phone',
#   {'fn_ratio': -0.25,
#    'fp_ratio': 0.2510121457489879,
#    'num_acts': 10,
#    'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Phone',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 34, 'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Post',
#   {'fn_ratio': -0.06211180124223603,
#    'fp_ratio': 0.0619195046439629,
#    'num_acts': 44,
#    'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('Inform-Police-Phone',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('NoOffer-Hotel-Internet',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Leave',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Select-Attraction-Area',
#   {'fn_ratio': -0.0888888888888888,
#    'fp_ratio': 0.0840615896795672,
#    'num_acts': 19,
#    'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-Post',
#   {'fn_ratio': 0.12121212121212122,
#    'fp_ratio': -0.12272603855552539,
#    'num_acts': 20,
#    'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-Addr',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 98, 'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-Phone',
#   {'fn_ratio': -0.06666666666666671,
#    'fp_ratio': 0.0717255717255717,
#    'num_acts': 22,
#    'tp_ratio': 0.0}),
#  ('Inform-Restaurant-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 10, 'tp_ratio': 0.0}),
#  ('Select-Hotel-Name',
#   {'fn_ratio': -0.06666666666666665,
#    'fp_ratio': 0.06701366297983086,
#    'num_acts': 19,
#    'tp_ratio': 0.0}),
#  ('Inform-Attraction-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Arrive',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Inform-Hospital-Phone',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 32, 'tp_ratio': 0.0}),
#  ('Select-Hotel-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('OfferBooked-Train-Day',
#   {'fn_ratio': -0.0910344827586207,
#    'fp_ratio': 0.09587855333389422,
#    'num_acts': 26,
#    'tp_ratio': 0.0}),
#  ('NoOffer-Hotel-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Select-Attraction-Name',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 12, 'tp_ratio': 0.0}),
#  ('Inform-Booking-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('OfferBooked-Train-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 10, 'tp_ratio': 0.0}),
#  ('Inform-Train-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-Name',
#   {'fn_ratio': -0.07500000000000001,
#    'fp_ratio': 0.09230769230769242,
#    'num_acts': 13,
#    'tp_ratio': 0.0}),
#  ('Recommend-Attraction-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-Dest',
#   {'fn_ratio': -0.08333333333333331,
#    'fp_ratio': 0.10588235294117654,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('OfferBook-Train-Ticket',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Inform-Hotel-Ref',
#   {'fn_ratio': -0.5,
#    'fp_ratio': 0.4444444444444444,
#    'num_acts': 6,
#    'tp_ratio': 0.0}),
#  ('Recommend-Hotel-Post',
#   {'fn_ratio': -0.375,
#    'fp_ratio': 0.34782608695652173,
#    'num_acts': 13,
#    'tp_ratio': 0.0}),
#  ('NoOffer-Hotel-Parking',
#   {'fn_ratio': 0.25,
#    'fp_ratio': -0.21052631578947367,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('Inform-Attraction-Price',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 18, 'tp_ratio': 0.0}),
#  ('Recommend-Attraction-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Select-Train-Arrive',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 6, 'tp_ratio': 0.0}),
#  ('Select-Restaurant-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('NoBook-Booking-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('NoOffer-Train-none',
#   {'fn_ratio': 0.25,
#    'fp_ratio': -0.21052631578947367,
#    'num_acts': 7,
#    'tp_ratio': 0.0}),
#  ('Select-Attraction-Price',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 4, 'tp_ratio': 0.0}),
#  ('Select-Train-Day',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 8, 'tp_ratio': 0.0}),
#  ('OfferBook-Train-Ref',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Attraction-Choice',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Recommend-Restaurant-none',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Select-Train-Id',
#   {'fn_ratio': 0.0, 'fp_ratio': 0.0, 'num_acts': 2, 'tp_ratio': 0.0}),
#  ('Inform-Attraction-Phone',
#   {'fn_ratio': -0.014166174580633073,
#    'fp_ratio': 0.014272319279773737,
#    'num_acts': 480,
#    'tp_ratio': -0.00013889853462045916}),
#  ('Request-Hotel-Type',
#   {'fn_ratio': 0.05591262639712924,
#    'fp_ratio': -0.054035842635888925,
#    'num_acts': 58,
#    'tp_ratio': -0.0023809523809523725}),
#  ('Request-Booking-Time',
#   {'fn_ratio': 0.007651106499191457,
#    'fp_ratio': 4.330733446855639e-08,
#    'num_acts': 260,
#    'tp_ratio': -0.007692307692307665}),
#  ('Inform-Hotel-Addr',
#   {'fn_ratio': 0.021314845599462673,
#    'fp_ratio': -0.013544754801132985,
#    'num_acts': 423,
#    'tp_ratio': -0.007780709207172554}),
#  ('Inform-Hotel-Parking',
#   {'fn_ratio': -0.043269480269885,
#    'fp_ratio': 0.05110755833414235,
#    'num_acts': 309,
#    'tp_ratio': -0.007798742138364845}),
#  ('Inform-Attraction-Addr',
#   {'fn_ratio': 0.028957937600983197,
#    'fp_ratio': -0.021120824061996557,
#    'num_acts': 1080,
#    'tp_ratio': -0.007841684418511324}),
#  ('Inform-Attraction-Type',
#   {'fn_ratio': -0.024826829247553528,
#    'fp_ratio': 0.0332580411104722,
#    'num_acts': 885,
#    'tp_ratio': -0.00840078489085111}),
#  ('Inform-Hotel-Post',
#   {'fn_ratio': 0.042300837232042476,
#    'fp_ratio': -0.03226416955994585,
#    'num_acts': 190,
#    'tp_ratio': -0.009865868528987916}),
#  ('Inform-Hotel-Area',
#   {'fn_ratio': 0.007503194843671901,
#    'fp_ratio': 0.005074782575657327,
#    'num_acts': 590,
#    'tp_ratio': -0.01257124471410187}),
#  ('bye-general-none',
#   {'fn_ratio': -0.025613986828762876,
#    'fp_ratio': 0.03839817969054789,
#    'num_acts': 2032,
#    'tp_ratio': -0.01278577049968399}),
#  ('Request-Restaurant-Food',
#   {'fn_ratio': 0.03287694144122554,
#    'fp_ratio': -0.01898863561976008,
#    'num_acts': 380,
#    'tp_ratio': -0.013962765957446832}),
#  ('Inform-Taxi-Car',
#   {'fn_ratio': 0.049511994430182615,
#    'fp_ratio': -0.03409919865630634,
#    'num_acts': 635,
#    'tp_ratio': -0.01545654893084758}),
#  ('NoOffer-Hotel-Price',
#   {'fn_ratio': 0.04289024447912235,
#    'fp_ratio': -0.02504680685154237,
#    'num_acts': 55,
#    'tp_ratio': -0.018518518518518545}),
#  ('Select-Hotel-Price',
#   {'fn_ratio': 0.18788978898503086,
#    'fp_ratio': -0.17252416080609423,
#    'num_acts': 53,
#    'tp_ratio': -0.01884057971014491}),
#  ('Inform-Restaurant-Price',
#   {'fn_ratio': 0.03237855377783494,
#    'fp_ratio': -0.013355343081885324,
#    'num_acts': 575,
#    'tp_ratio': -0.019056261343012748}),
#  ('Request-Train-Day',
#   {'fn_ratio': -0.04015842469539569,
#    'fp_ratio': 0.0627873129837342,
#    'num_acts': 441,
#    'tp_ratio': -0.022671114405732662}),
#  ('Inform-Train-Id',
#   {'fn_ratio': 0.027689163846098097,
#    'fp_ratio': -0.0037798031735547244,
#    'num_acts': 870,
#    'tp_ratio': -0.023897602841077226}),
#  ('NoBook-Booking-none',
#   {'fn_ratio': 0.05627839417140018,
#    'fp_ratio': -0.029442775412938146,
#    'num_acts': 236,
#    'tp_ratio': -0.027011494252873525}),
#  ('Inform-Train-Day',
#   {'fn_ratio': -0.00014830423300027373,
#    'fp_ratio': 0.029303094433353487,
#    'num_acts': 252,
#    'tp_ratio': -0.029233870967741882}),
#  ('Recommend-Attraction-Addr',
#   {'fn_ratio': -0.0043322859248665635,
#    'fp_ratio': 0.03507808721064104,
#    'num_acts': 157,
#    'tp_ratio': -0.03037686809616634}),
#  ('NoOffer-Hotel-Area',
#   {'fn_ratio': -0.09142770068856482,
#    'fp_ratio': 0.12457031574513794,
#    'num_acts': 51,
#    'tp_ratio': -0.031055900621118016}),
#  ('Select-Restaurant-Name',
#   {'fn_ratio': -0.07110663814397944,
#    'fp_ratio': 0.10779938309093712,
#    'num_acts': 81,
#    'tp_ratio': -0.03562653562653563}),
#  ('Request-Booking-People',
#   {'fn_ratio': 0.029728050377047066,
#    'fp_ratio': 0.006957331713312753,
#    'num_acts': 263,
#    'tp_ratio': -0.03689567430025442}),
#  ('Select-Train-none',
#   {'fn_ratio': 0.03825122275734116,
#    'fp_ratio': 0.0,
#    'num_acts': 54,
#    'tp_ratio': -0.037037037037037035}),
#  ('Recommend-Hotel-Type',
#   {'fn_ratio': 0.014868518063406277,
#    'fp_ratio': 0.026123455021921205,
#    'num_acts': 51,
#    'tp_ratio': -0.04}),
#  ('Inform-Train-Time',
#   {'fn_ratio': 0.03624529053001152,
#    'fp_ratio': 0.010464226450858288,
#    'num_acts': 300,
#    'tp_ratio': -0.04675763367260766}),
#  ('Book-Booking-People',
#   {'fn_ratio': 0.05100038552833808,
#    'fp_ratio': -4.562978112021554e-07,
#    'num_acts': 236,
#    'tp_ratio': -0.050847457627118633}),
#  ('welcome-general-none',
#   {'fn_ratio': 0.04919568165921112,
#    'fp_ratio': 0.0019723805894512414,
#    'num_acts': 1007,
#    'tp_ratio': -0.05122834422039191}),
#  ('Inform-Taxi-Leave',
#   {'fn_ratio': 0.05377088664759899,
#    'fp_ratio': -1.1643566971114572e-05,
#    'num_acts': 38,
#    'tp_ratio': -0.05263157894736842}),
#  ('Request-Hotel-Stars',
#   {'fn_ratio': 0.07031761922096835,
#    'fp_ratio': -0.017700155930419792,
#    'num_acts': 91,
#    'tp_ratio': -0.0531400966183575}),
#  ('NoOffer-Restaurant-Food',
#   {'fn_ratio': 0.03719499285355593,
#    'fp_ratio': 0.01711500648011119,
#    'num_acts': 178,
#    'tp_ratio': -0.05429292929292928}),
#  ('Request-Booking-Day',
#   {'fn_ratio': 0.05634810990544423,
#    'fp_ratio': 1.10773201167369e-07,
#    'num_acts': 460,
#    'tp_ratio': -0.05652173913043479}),
#  ('Select-Hotel-Stars',
#   {'fn_ratio': 0.0935344827586207,
#    'fp_ratio': -0.033776580646119214,
#    'num_acts': 33,
#    'tp_ratio': -0.058823529411764705}),
#  ('NoOffer-Restaurant-Price',
#   {'fn_ratio': 0.12152955875583615,
#    'fp_ratio': -0.04557578897959706,
#    'num_acts': 39,
#    'tp_ratio': -0.07631578947368428}),
#  ('Select-Restaurant-Area',
#   {'fn_ratio': 0.26626506024096375,
#    'fp_ratio': -0.18318447995511042,
#    'num_acts': 16,
#    'tp_ratio': -0.07936507936507936}),
#  ('Book-Booking-Stay',
#   {'fn_ratio': 0.05286499373661446,
#    'fp_ratio': 0.0276624088508641,
#    'num_acts': 106,
#    'tp_ratio': -0.07977207977207978}),
#  ('NoBook-Booking-Stay',
#   {'fn_ratio': 0.03642224012892825,
#    'fp_ratio': 0.05677040803259903,
#    'num_acts': 25,
#    'tp_ratio': -0.08974358974358973}),
#  ('Inform-Taxi-Depart',
#   {'fn_ratio': 0.04267575571964671,
#    'fp_ratio': 0.04892492449101804,
#    'num_acts': 96,
#    'tp_ratio': -0.09043478260869564}),
#  ('NoOffer-Hotel-Stars',
#   {'fn_ratio': 0.19784963860160948,
#    'fp_ratio': -0.08203261188119704,
#    'num_acts': 47,
#    'tp_ratio': -0.11454545454545455}),
#  ('Inform-Booking-People',
#   {'fn_ratio': 0.16589147286821704,
#    'fp_ratio': -0.03811268607336249,
#    'num_acts': 31,
#    'tp_ratio': -0.125}),
#  ('Request-Attraction-Name',
#   {'fn_ratio': 0.13270572222537286,
#    'fp_ratio': 1.548458042993639e-05,
#    'num_acts': 30,
#    'tp_ratio': -0.13333333333333336}),
#  ('OfferBooked-Train-Dest',
#   {'fn_ratio': 0.1860162601626016,
#    'fp_ratio': -6.024131699705615e-05,
#    'num_acts': 22,
#    'tp_ratio': -0.18181818181818182}),
#  ('Select-Restaurant-Price',
#   {'fn_ratio': 0.13861554308757773,
#    'fp_ratio': 0.06893476343120974,
#    'num_acts': 67,
#    'tp_ratio': -0.20625}),
#  ('Select-Attraction-Fee',
#   {'fn_ratio': 0.5080321285140562,
#    'fp_ratio': -0.2726153509431897,
#    'num_acts': 15,
#    'tp_ratio': -0.2222222222222222}),
#  ('OfferBooked-Train-Time',
#   {'fn_ratio': 0.137218045112782,
#    'fp_ratio': 0.1277384046886772,
#    'num_acts': 11,
#    'tp_ratio': -0.26666666666666666}),
#  ('Inform-Taxi-none',
#   {'fn_ratio': 0.3492723492723492,
#    'fp_ratio': 0.0,
#    'num_acts': 12,
#    'tp_ratio': -0.33333333333333337}),
#  ('NoOffer-Train-Depart',
#   {'fn_ratio': 0.19786096256684488,
#    'fp_ratio': 0.2118380062305296,
#    'num_acts': 7,
#    'tp_ratio': -0.41666666666666663}),
#  ('Inform-Police-Addr',
#   {'fn_ratio': 0.5, 'fp_ratio': 0.4, 'num_acts': 3, 'tp_ratio': -1.0})]

# %%
ppo_win_turns = search_ppo_win_turns(ids='Request-Taxi-Leave',
                                     result_gpt2=result_gpt2_milu_0,
                                     result_ppo=result_ppo_milu_0)
pprint(ppo_win_turns)
# Out:
# [{'action': ['Request-Taxi-Arrive-?', 'Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Booking-Time-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time would you like to eat or arrive by?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': ['Request-Taxi-Arrive-?'],
#           'fp_acts': ['Request-Taxi-Depart-?'],
#           'gen_text': 'When would you like to leave or arrive at the hotel by?',
#           'noised_text': 'When would you like to leave or of the hotel by?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Leave-?'],
#            'gen_text': 'What time would you like to leave?',
#            'noised_text': 'What anytime would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'What time would you like to be picked up?',
#           'noised_text': 'What time would you like to be picked up?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Booking-Time-?'],
#            'gen_text': 'What time would you like to leave?',
#            'noised_text': 'What time would like to weed?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'What time would you like to be picked up?',
#           'noised_text': 'What time would you like to be picked up?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Dest-?'],
#            'gen_text': 'I can help you with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I can help you with that. is your destination d '
#                           'what time would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Depart-?'],
#           'gen_text': 'Where would you like the taxi to pick you up and at '
#                       'what time?',
#           'noised_text': 'Where would you like the taxi to pick you up and at '
#                          'what time?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?']}},
#  {'action': ['Request-Taxi-Leave-?',
#              'Request-Taxi-Dest-?',
#              'greet-general-none-none'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?',
#                        'Request-Taxi-Dest-?',
#                        'greet-general-none-none'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Dest-?'],
#            'gen_text': 'I can help with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I can help that? What is your destination and Mario '
#                           'time would like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': ['Request-Taxi-Dest-?', 'greet-general-none-none'],
#           'fp_acts': ['Request-Taxi-Depart-?'],
#           'gen_text': "I'd be happy to help! Where would you like to be picked "
#                       'up, what time do you want to be picked up?',
#           'noised_text': "I'd be happy to help. would you like to be picked "
#                          'up, what time do you want to be picked up?',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': [],
#            'gen_text': 'What time would you like to leave?',
#            'noised_text': 'What would you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': [],
#           'gen_text': 'What time would you like to be picked up?',
#           'noised_text': 'What time do you like to be picked up',
#           'tp_acts': ['Request-Taxi-Leave-?']}},
#  {'action': ['Request-Taxi-Leave-?',
#              'Inform-Attraction-Phone-01223338300',
#              "Inform-Attraction-Addr-King 's Parade",
#              'Inform-Attraction-Post-CB21RL'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?',
#                        'Inform-Attraction-Phone-01223338300',
#                        "Inform-Attraction-Addr-King 's Parade"],
#            'fp_acts': ['Request-Train-Leave-?'],
#            'gen_text': "The address is King's Parade, CB21RL. The phone number "
#                        'is 01223338300. What time would you like to leave?',
#            'noised_text': 'Deals King, Parade? CB21RL I, phone number is 8300 '
#                           'What time would me to leave that',
#            'tp_acts': ['Inform-Attraction-Post-CB21RL']},
#   'ppo': {'fn_acts': ['Inform-Attraction-Phone-01223338300',
#                       "Inform-Attraction-Addr-King 's Parade"],
#           'fp_acts': ["Inform-Attraction-Addr-'s",
#                       'Inform-Hotel-Name-played',
#                       'Inform-Hotel-Name-King'],
#           'gen_text': "The address is King's Parade, postcode CB21RL. The "
#                       'phone number is 01223338300. What time would you like '
#                       'to be picked up?',
#           'noised_text': "The address is King's played. postcode CB21RL. phone "
#                          "number're 0. What time would you to be picked up?",
#           'tp_acts': ['Request-Taxi-Leave-?',
#                       'Inform-Attraction-Post-CB21RL']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#            'fp_acts': [],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What like to leave our arrive whole?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#           'gen_text': 'When would you like to leave or arrive by?',
#           'noised_text': 'When would he like to leave or arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?'],
#            'fp_acts': ['Request-Train-Arrive-?'],
#            'gen_text': 'What time would you like to leave or arrive by?',
#            'noised_text': 'What time would you like got or arrive by?',
#            'tp_acts': ['Request-Taxi-Arrive-?']},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Arrive-?'],
#           'gen_text': 'When would you like to leave or arrive by?',
#           'noised_text': 'When would you like to leave or arrive by?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Arrive-?']}},
#  {'action': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#   'gpt2': {'fn_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?'],
#            'fp_acts': ['Request-Train-Leave-?', 'Request-Train-Dest-?'],
#            'gen_text': 'I can help you with that. What is your destination and '
#                        'what time would you like to leave?',
#            'noised_text': 'I help you with that. What your destination and '
#                           'what time of you like to leave?',
#            'tp_acts': []},
#   'ppo': {'fn_acts': [],
#           'fp_acts': ['Request-Taxi-Depart-?'],
#           'gen_text': 'Where would you like the taxi to pick you up and at '
#                       'what time?',
#           'noised_text': 'Where would you like the taxi to pick you up and at '
#                          'what time?',
#           'tp_acts': ['Request-Taxi-Leave-?', 'Request-Taxi-Dest-?']}}]
